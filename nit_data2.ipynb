# %%
def divide(a,b):
    if(b==0):
        print("can't be divided by zero")
    else:
        return a/b;

divide(22,7)
# Out:
# 3.142857142857143

# %%
def getName(name):
    print("Hello", name)

getName("Zainab")
getName("Aastha")
getName("Simran")
# Out:
# Hello Zainab
# Hello Aastha
# Hello Simran
